# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset_path='https://frenzy86.s3.eu-west-2.amazonaws.com/fav/tips.csv'
tips = pd.read_csv(dataset_path, )
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set(color_codes=True)
tips = sns.load_dataset("tips")

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.countplot(x = tips["smoker"]);

# %%
sns.countplot(x = tips["sex"]);

# %%
sns.countplot(x = tips["day"]);
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x = tips["time"]);
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.countplot(y = tips["time"]);
# Out:
# <AxesSubplot:xlabel='count', ylabel='time'>

# %%
pd.plotting.scatter_matrix(tips, figsize=(15,8));

# %%
## Categorical = 'sex', 'smoker' , 'day', 'time' , 'size'

# %%
sns.pairplot(tips, hue="sex");

# %%
sns.pairplot(tips, hue="smoker");

# %%
sns.pairplot(tips, hue="day");

# %%
sns.pairplot(tips, hue="time");

# %%
sns.pairplot(tips, hue="size");

# %%
sns.relplot(data=tips, row="sex", x="total_bill", y="tip", col="time", hue="day");
