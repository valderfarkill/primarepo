# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
generate_random = np.random.RandomState(667)
x = 10 * generate_random.rand(100)

#noise = np.random.xxxxxxx
#y =  3 * x + noise

# %%
noise = np.random.standard_normal(100)
y = 3 * x + noise

# %%
noise
# Out:
# array([ 0.05527256,  1.21172617,  0.81423107, -1.40161611,  0.13900476,
#         0.44724514,  0.08374935,  1.165935  ,  1.41044508, -1.05476079,
#         0.08844887, -1.56594119, -0.61624498, -0.4574475 ,  0.09680929,
#        -0.0211362 ,  1.14069777, -0.88964452, -0.20735486, -1.82259048,
#        -0.41947972,  0.60652582, -0.26917207,  0.82698157,  2.34304548,
#        -0.89916495, -0.6348122 ,  1.30179522,  0.2038735 , -1.28924346,
#        -0.25221992, -0.33738931,  1.10900478,  0.16725416, -0.56394608,
#        -2.0094942 ,  0.13441703,  0.43112829, -1.48899478,  2.29449228,
#         2.06818793, -0.93506101,  0.09992472,  0.70114141,  0.8129324 ,
#        -1.03431927,  0.18639377, -0.33539201, -0.73523796, -0.42561338,
#        -0.60667848,  0.87592023,  0.97397904,  1.14103128, -0.38357728,
#        -0.45375802, -1.57245243,  0.1536272 ,  1.47201246, -0.72883093,
#        -0.73403571, -0.05327604, -0.66771062, -0.83332628,  0.67382381,
#         1.2186644 ,  0.1642808 ,  0.90053484,  0.93071702, -2.03091142,
#         0.50964589,  0.54634801, -0.64056209, -0.98119175, -1.49724849,
#        -0.40759208, -0.16045024,  1.09967457,  0.66049239,  0.0328998 ,
#         1.39006566,  0.01452626,  1.22201694, -1.25928621, -0.085269  ,
#         0.05587777, -2.16448863,  0.11227794,  0.18277166,  0.94770814,
#         0.5849394 , -1.8513651 ,  0.25890501, -1.07669774, -0.446349  ,
#         0.31150459,  0.65433945,  1.50941961, -0.10193778, -2.47754121])

# %%
plt.figure(figsize= (6, 4))

plt.scatter(x, y)

# %%
from sklearn.model_selection import train_test_split

# %%
X = x.reshape(-1 ,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.2, 
                                                    random_state = 667
                                                    )

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

# %%
plt.plot(y_test_pred)
plt.plot(y_test)
